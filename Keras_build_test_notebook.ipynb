# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaKane2001/keras_build_test/blob/main/Keras_build_test_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Keras build test notebook
#
# Keras has taken a step towards improving developer experience by hosting the codebase in a separate repository. This drastically improves testing times and is a catalyst for rapid open source development.
#
# This notebook is a ready-to-use notebook for testing of Keras modules. This notebook does the following things:
# 1. Sets up the environment (venv, bazel, etc.)
# 2. Clones your fork.
# 3. Runs tests.
#
# You can specify which tests to run. A sample test is shown here. It is not recommended to run all tests in Colab, since it takes a lot of time.
#
# For more information, see [CONTRIBUTING.md](https://github.com/keras-team/keras/blob/master/CONTRIBUTING.md) and [bazel test docs](https://docs.bazel.build/versions/main/skylark/testing.html).

# %% [markdown]
# Enter your GitHub username and name of the branch to be cloned here.

# %%
USERNAME = 'keras-team' #@param {type:"string"}
BRANCH = 'master' #@param {type:"string"}

# %% [markdown]
# ## Setup

# %%
# %%capture

#Install bazel
BAZEL_VERSION = '4.2.1'
# !wget https://github.com/bazelbuild/bazel/releases/download/{BAZEL_VERSION}/bazel-{BAZEL_VERSION}-installer-linux-x86_64.sh
# !chmod +x bazel-{BAZEL_VERSION}-installer-linux-x86_64.sh
# !./bazel-{BAZEL_VERSION}-installer-linux-x86_64.sh
# !bazel

# Reinstall venv
# !apt-get update
# !apt-get install python3.7-dev python3.7-venv

# activate virtual env
# !mkdir keras_env
# !python3 -m venv keras_env
# !source keras_env/bin/activate

# Clone repo and install requirements
# !git clone -b $BRANCH https://github.com/$USERNAME/keras.git
# %cd keras
# !pip install -r requirements.txt
# !pip uninstall -y keras-nightly
# !pip install --upgrade tf-nightly

# %% [markdown]
# ## Tests
#
# Exclude the `.py` while metioning the file path.
#
# Syntax: `!bazel test [module path 1] [module path 2] [...]`

# %%
# !bazel test keras/layers/convolutional_test
# Out:
# Starting local Bazel server and connecting to it...
# WARNING: ignoring LD_PRELOAD in environment.
# WARNING: The following configs were expanded more than once: [v2]. For repeatable flags, repeats are counted twice and may lead to unexpected behavior.
# INFO: Options provided by the client:
#   Inherited 'common' options: --isatty=1 --terminal_columns=0
# INFO: Reading rc options for 'test' from /content/keras/.bazelrc:
#   Inherited 'build' options: --apple_platform_type=macos --define open_source_build=true --define=use_fast_cpp_protos=false --define=tensorflow_enable_mlir_generated_gpu_kernels=0 --define=allow_oversize_protos=true --spawn_strategy=standalone -c opt --announce_rc --define=grpc_no_ares=true --config=short_logs --config=v2
# INFO: Reading rc options for 'test' from /content/keras/.bazelrc:
#   'test' options: --define open_source_build=true --define=use_fast_cpp_protos=false --config=v2
# INFO: Found applicable config definition build:short_logs in file /content/keras/.bazelrc: --output_filter=DONT_MATCH_ANYTHING
# INFO: Found applicable config definition build:v2 in file /content/keras/.bazelrc: --define=tf_api_version=2 --action_env=TF2_BEHAVIOR=1
# INFO: Found applicable config definition build:v2 in file /content/keras/.bazelrc: --define=tf_api_version=2 --action_env=TF2_BEHAVIOR=1
# Loading: 0 packages loaded
# Loading: 0 packages loaded
# Loading: 0 packages loaded
# Loading: 0 packages loaded
#     Fetching @com_google_protobuf; fetching
# Loading: 0 packages loaded
#     Fetching @com_google_protobuf; fetching
# Loading: 0 packages loaded
#     Fetching @com_google_protobuf; fetching
# Loading: 0 packages loaded
#     Fetching @com_google_protobuf; fetching
# Loading: 0 packages loaded
#     Fetching @com_google_protobuf; fetching
#     Fetching ...otobuf; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/com_google_protobuf/temp4567191513759322271/v3.9\
# Loading: 0 packages loaded
# Analyzing: target //keras/layers:convolutional_test (1 packages loaded, 0 targ\
# Analyzing: target //keras/layers:convolutional_test (2 packages loaded, 0 targ\
# ets configured)
# Analyzing: target //keras/layers:convolutional_test (6 packages loaded, 7 targ\
# ets configured)
# Analyzing: target //keras/layers:convolutional_test (10 packages loaded, 7 tar\
# Analyzing: target //keras/layers:convolutional_test (17 packages loaded, 24 ta\
# Analyzing: target //keras/layers:convolutional_test (17 packages loaded, 24 ta\
# rgets configured)
# Analyzing: target //keras/layers:convolutional_test (17 packages loaded, 24 ta\
# rgets configured)
# Analyzing: target //keras/layers:convolutional_test (17 packages loaded, 24 ta\
# Analyzing: target //keras/layers:convolutional_test (28 packages loaded, 31 ta\
# rgets configured)
# Analyzing: target //keras/layers:convolutional_test (35 packages loaded, 53 ta\
# Analyzing: target //keras/layers:convolutional_test (41 packages loaded, 120 t\
# argets configured)
#     currently loading: @com_google_protobuf//
# Analyzing: target //keras/layers:convolutional_test (41 packages loaded, 129 t\
# argets configured)
#     currently loading: @com_google_protobuf//
#     Fetching @remote_coverage_tools; fetching
# Analyzing: target //keras/layers:convolutional_test (42 packages loaded, 129 t\
# argets configured)
#     Fetching @remote_coverage_tools; fetching
# Analyzing: target //keras/layers:convolutional_test (42 packages loaded, 129 t\
# argets configured)
#     Fetching @remote_coverage_tools; fetching
#     Fetching ..._tools; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remote_coverage_tools/temp12339349057625869/cove\
# Analyzing: target //keras/layers:convolutional_test (43 packages loaded, 232 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
#     Fetching https://mirror.bazel.build/...11.0.6-linux_x64.tar.gz; 7,110,608B
# Analyzing: target //keras/layers:convolutional_test (43 packages loaded, 232 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
#     Fetching https://mirror.bazel.build/...1.0.6-linux_x64.tar.gz; 12,804,000B
#     Fetching @zlib; fetching
# Analyzing: target //keras/layers:convolutional_test (43 packages loaded, 232 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
#     Fetching https://mirror.bazel.build/...1.0.6-linux_x64.tar.gz; 21,307,232B
#     Fetching @zlib; fetching
# Analyzing: target //keras/layers:convolutional_test (43 packages loaded, 232 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
#     Fetching https://mirror.bazel.build/...1.0.6-linux_x64.tar.gz; 29,204,272B
# Analyzing: target //keras/layers:convolutional_test (45 packages loaded, 511 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (46 packages loaded, 664 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
#     Fetching https://mirror.bazel.build/...1.0.6-linux_x64.tar.gz; 39,509,728B
# Analyzing: target //keras/layers:convolutional_test (47 packages loaded, 720 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (50 packages loaded, 751 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (50 packages loaded, 830 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (50 packages loaded, 880 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (50 packages loaded, 889 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (50 packages loaded, 891 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (50 packages loaded, 894 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (50 packages loaded, 933 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (50 packages loaded, 994 t\
# argets configured)
#     Fetching @remotejdk11_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (50 packages loaded, 1007 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching
#     Fetching https://mirror.bazel.build/....0.6-linux_x64.tar.gz; 121,707,616B
#     Fetching @remote_java_tools_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching
#     Fetching https://mirror.bazel.build/....0.6-linux_x64.tar.gz; 127,687,744B
#     Fetching @remote_java_tools_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 4s
#     Fetching https://mirror.bazel.build/...6-linux_x64.tar.gz; 134,847,488B 4s
#     Fetching @remote_java_tools_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 4s
#     Fetching https://mirror.bazel.build/...6-linux_x64.tar.gz; 140,893,136B 4s
#     Fetching @remote_java_tools_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 4s
#     Fetching https://mirror.bazel.build/...6-linux_x64.tar.gz; 148,954,000B 4s
#     Fetching @remote_java_tools_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 4s
#     Fetching https://mirror.bazel.build/...6-linux_x64.tar.gz; 154,000,240B 4s
#     Fetching @remote_java_tools_linux; fetching
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 5s
#     Fetching https://mirror.bazel.build/...6-linux_x64.tar.gz; 158,456,656B 4s
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 5s
#     Fetching https://mirror.bazel.build/...6-linux_x64.tar.gz; 161,356,608B 5s
#     Fetching @remote_java_tools_linux; fetching
#     Fetching ..._linux; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remote_java_tools_linux/temp14870747643502763262\
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 5s
#     Fetching https://mirror.bazel.build/...6-linux_x64.tar.gz; 168,418,048B 5s
#     Fetching @remote_java_tools_linux; fetching
#     Fetching ..._linux; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remote_java_tools_linux/temp14870747643502763262\
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 5s
#     Fetching https://mirror.bazel.build/...6-linux_x64.tar.gz; 177,961,664B 5s
#     Fetching @remote_java_tools_linux; fetching
#     Fetching ..._linux; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remote_java_tools_linux/temp14870747643502763262\
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 5s
#     Fetching https://mirror.bazel.build/...6-linux_x64.tar.gz; 189,504,096B 5s
#     Fetching @remote_java_tools_linux; fetching
#     Fetching ..._linux; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remote_java_tools_linux/temp14870747643502763262\
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 6s
#     Fetching @remote_java_tools_linux; fetching
#     Fetching ..._linux; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remote_java_tools_linux/temp14870747643502763262\
# Analyzing: target //keras/layers:convolutional_test (52 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 6s
#     Fetching @remote_java_tools_linux; fetching
#     Fetching ..._linux; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remote_java_tools_linux/temp14870747643502763262\
# /java_tools_javac11_linux-v10.6.zip
#     Fetching ..._linux; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remotejdk11_linux/temp15629557003974885926/zulu1\
# Analyzing: target //keras/layers:convolutional_test (53 packages loaded, 1052 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 6s
#     Fetching ..._linux; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remotejdk11_linux/temp15629557003974885926/zulu1\
# Analyzing: target //keras/layers:convolutional_test (53 packages loaded, 1079 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 7s
#     Fetching ..._linux; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remotejdk11_linux/temp15629557003974885926/zulu1\
# Analyzing: target //keras/layers:convolutional_test (53 packages loaded, 1079 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 8s
#     Fetching ..._linux; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remotejdk11_linux/temp15629557003974885926/zulu1\
# Analyzing: target //keras/layers:convolutional_test (53 packages loaded, 1079 \
# targets configured)
#     Fetching @remotejdk11_linux; fetching 9s
#     Fetching ..._linux; Extracting /root/.cache/bazel/_bazel_root/26321c5950fe\
# 518aef514f9fb14403c6/external/remotejdk11_linux/temp15629557003974885926/zulu1\
# Analyzing: target //keras/layers:convolutional_test (53 packages loaded, 1079 \
# targets configured)
# INFO: Analyzed target //keras/layers:convolutional_test (54 packages loaded, 1217 targets configured).
# INFO: Found 1 test target...
# [8 / 188] 2 actions running
#     Compiling src/google/protobuf/compiler/main.cc [for host]; 0s local
# [8 / 188] 2 actions running
#     Compiling src/google/protobuf/compiler/main.cc [for host]; 1s local
# [9 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [9 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [10 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/compiler/plugin.pb.cc [for host]; 0s local
# [10 / 188] 2 actions running
#     Compiling src/google/protobuf/compiler/plugin.pb.cc [for host]; 1s local
# [10 / 188] 2 actions running
#     Compiling src/google/protobuf/compiler/plugin.pb.cc [for host]; 2s local
# [11 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/compiler/plugin.pb.cc [for host]; 2s local
# [12 / 188] 2 actions running
#     Compiling inflate.c [for host]; 0s local
# [13 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [13 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [14 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [14 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [14 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [14 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [15 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 3s local
# [15 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [16 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [16 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [17 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [17 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [17 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [18 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 3s local
# [18 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [19 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [20 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [21 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [21 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [21 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [22 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [22 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [22 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [23 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 3s local
# [23 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [24 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [25 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [25 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [26 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [26 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [26 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [27 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 3s local
# [27 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [28 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 4s local
# [30 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [30 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [31 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [31 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [32 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [32 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [32 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [33 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [33 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [33 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [34 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [34 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [35 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [35 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [36 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/message_lite.cc [for host]; 1s local
# [36 / 188] 2 actions running
#     Compiling src/google/protobuf/message_lite.cc [for host]; 1s local
# [37 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/stubs/status.cc [for host]; 0s local
# [38 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [39 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [39 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [40 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [40 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [40 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [41 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/repeated_field.cc [for host]; 1s local
# [41 / 188] 2 actions running
#     Compiling src/google/protobuf/repeated_field.cc [for host]; 2s local
# [41 / 188] 2 actions running
#     Compiling src/google/protobuf/repeated_field.cc [for host]; 3s local
# [42 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [42 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [42 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [42 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [43 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 3s local
# [43 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 4s local
# [43 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 5s local
# [43 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 6s local
# [44 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 6s local
# [44 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 7s local
# [45 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 7s local
# [45 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 8s local
# [45 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 9s local
# [46 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [46 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [47 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [47 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [48 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [48 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [48 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [49 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [49 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [49 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [50 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [50 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [51 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [51 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [51 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [52 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 2s local
# [53 / 188] 2 actions running
#     Compiling src/google/protobuf/generated_enum_util.cc [for host]; 0s local
# [54 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [54 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [54 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [55 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [55 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [56 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 0s local
# [56 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [56 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 1s local
# [57 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [57 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [57 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [57 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 4s local
# [58 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [58 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [58 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 4s local
# [58 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 5s local
# [59 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [59 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [59 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 4s local
# [60 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 1s local
# [60 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 2s local
# [61 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 2s local
# [61 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 3s local
# [62 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [62 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [62 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [62 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [63 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [64 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [64 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [65 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [65 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [66 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [66 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [66 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [66 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [67 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [67 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [67 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 4s local
# [68 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 1s local
# [68 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 2s local
# [69 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 1s local
# [70 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [71 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 0s local
# [71 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [72 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 1s local
# [72 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 1s local
# [73 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [73 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [73 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 1s local
# [73 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 2s local
# [74 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 2s local
# [74 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 3s local
# [75 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [75 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [76 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 1s local
# [76 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 1s local
# [77 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [77 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [77 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 1s local
# [77 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 2s local
# [78 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [78 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [78 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 4s local
# [78 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 5s local
# [79 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 5s local
# [80 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 6s local
# [80 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 6s local
# [81 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 6s local
# [81 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 7s local
# [81 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 8s local
# [82 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 8s local
# [82 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 9s local
# [83 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/source_context.pb.cc [for host]; 1s local
# [83 / 188] 2 actions running
#     Compiling src/google/protobuf/source_context.pb.cc [for host]; 1s local
# [84 / 188] 2 actions running
#     Compiling src/google/protobuf/service.cc [for host]; 0s local
# [85 / 188] 2 actions running
#     Compiling src/google/protobuf/reflection_ops.cc [for host]; 0s local
# [85 / 188] 2 actions running
#     Compiling src/google/protobuf/reflection_ops.cc [for host]; 1s local
# [86 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [86 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [87 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 0s local
# [87 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 1s local
# [87 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 2s local
# [88 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 2s local
# [88 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 2s local
# [89 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/io/printer.cc [for host]; 1s local
# [90 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [90 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [90 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [90 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [91 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [92 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [92 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 1s local
# [93 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 1s local
# [93 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 1s local
# [93 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 2s local
# [93 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 3s local
# [94 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 3s local
# [95 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [95 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 4s local
# [95 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 5s local
# [96 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 5s local
# [96 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 6s local
# [97 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 7s local
# [97 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 7s local
# [98 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [98 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [99 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/descriptor.pb.cc [for host]; 1s local
# [99 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.pb.cc [for host]; 1s local
# [99 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.pb.cc [for host]; 2s local
# [99 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.pb.cc [for host]; 3s local
# [99 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.pb.cc [for host]; 4s local
# [99 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.pb.cc [for host]; 5s local
# [99 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.pb.cc [for host]; 6s local
# [99 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.pb.cc [for host]; 7s local
# [99 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.pb.cc [for host]; 8s local
# [100 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/descriptor.cc [for host]; 7s local
# [100 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.cc [for host]; 8s local
# [100 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.cc [for host]; 9s local
# [100 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.cc [for host]; 10s local
# [100 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.cc [for host]; 11s local
# [100 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.cc [for host]; 12s local
# [101 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/descriptor.cc [for host]; 12s local
# [101 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.cc [for host]; 12s local
# [101 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.cc [for host]; 13s local
# [102 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/descriptor.cc [for host]; 13s local
# [102 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor.cc [for host]; 14s local
# [103 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [104 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/any.pb.cc [for host]; 1s local
# [104 / 188] 2 actions running
#     Compiling src/google/protobuf/any.pb.cc [for host]; 1s local
# [106 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/any.cc [for host]; 0s local
# [106 / 188] 2 actions running
#     Compiling src/google/protobuf/any.cc [for host]; 0s local
# [107 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 0s local
# [107 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [108 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [108 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [108 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [109 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [110 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [110 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [111 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/type.pb.cc [for host]; 2s local
# [111 / 188] 2 actions running
#     Compiling src/google/protobuf/type.pb.cc [for host]; 2s local
# [112 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [112 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [113 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [113 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [113 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [114 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 3s local
# [115 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 3s local
# [115 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [115 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 4s local
# [115 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 5s local
# [116 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [116 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [117 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [117 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [118 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/stubs/bytestream.cc [for host]; 0s local
# [119 / 188] 2 actions running
#     Compiling src/google/protobuf/wire_format_lite.cc [for host]; 0s local
# [119 / 188] 2 actions running
#     Compiling src/google/protobuf/wire_format_lite.cc [for host]; 1s local
# [120 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [120 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [121 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [122 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [123 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [123 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [123 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [124 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [124 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [125 / 188] 2 actions running
#     Compiling src/google/protobuf/text_format.cc [for host]; 0s local
# [126 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/text_format.cc [for host]; 1s local
# [126 / 188] 2 actions running
#     Compiling src/google/protobuf/text_format.cc [for host]; 1s local
# [126 / 188] 2 actions running
#     Compiling src/google/protobuf/text_format.cc [for host]; 2s local
# [126 / 188] 2 actions running
#     Compiling src/google/protobuf/text_format.cc [for host]; 3s local
# [126 / 188] 2 actions running
#     Compiling src/google/protobuf/text_format.cc [for host]; 4s local
# [127 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 4s local
# [127 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 4s local
# [127 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 5s local
# [128 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [128 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [129 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/unknown_field_set.cc [for host]; 0s local
# [129 / 188] 2 actions running
#     Compiling src/google/protobuf/unknown_field_set.cc [for host]; 1s local
# [130 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/wire_format.cc [for host]; 0s local
# [130 / 188] 2 actions running
#     Compiling src/google/protobuf/wire_format.cc [for host]; 0s local
# [130 / 188] 2 actions running
#     Compiling src/google/protobuf/wire_format.cc [for host]; 1s local
# [130 / 188] 2 actions running
#     Compiling src/google/protobuf/wire_format.cc [for host]; 2s local
# [131 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/wire_format.cc [for host]; 3s local
# [131 / 188] 2 actions running
#     Compiling src/google/protobuf/wire_format.cc [for host]; 3s local
# [132 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [132 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [133 / 188] 2 actions running
#     @com_google_protobuf//:protobuf_lite; 0s local
# [133 / 188] 2 actions running
#     @com_google_protobuf//:protobuf_lite; 0s local
# [134 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/extension_set.cc [for host]; 0s local
# [134 / 188] 2 actions running
#     Compiling src/google/protobuf/extension_set.cc [for host]; 0s local
# [135 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/extension_set.cc [for host]; 1s local
# [135 / 188] 2 actions running
#     Compiling src/google/protobuf/extension_set.cc [for host]; 1s local
# [135 / 188] 2 actions running
#     Compiling src/google/protobuf/extension_set.cc [for host]; 2s local
# [136 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf_lite; 2s local
# [136 / 188] 2 actions running
#     @com_google_protobuf//:protobuf_lite; 2s local
# [136 / 188] 2 actions running
#     @com_google_protobuf//:protobuf_lite; 3s local
# [137 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf_lite; 3s local
# [137 / 188] 2 actions running
#     @com_google_protobuf//:protobuf_lite; 4s local
# [138 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/parse_context.cc [for host]; 0s local
# [138 / 188] 2 actions running
#     Compiling src/google/protobuf/parse_context.cc [for host]; 1s local
# [139 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/timestamp.pb.cc [for host]; 1s local
# [139 / 188] 2 actions running
#     Compiling src/google/protobuf/timestamp.pb.cc [for host]; 1s local
# [141 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf_lite; 0s local
# [141 / 188] 2 actions running
#     @com_google_protobuf//:protobuf_lite; 0s local
# [142 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [142 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [142 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [143 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/struct.pb.cc [for host]; 2s local
# [144 / 188] 2 actions running
#     Compiling src/google/protobuf/struct.pb.cc [for host]; 2s local
# [144 / 188] 2 actions running
#     Compiling src/google/protobuf/struct.pb.cc [for host]; 3s local
# [145 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/message.cc [for host]; 1s local
# [145 / 188] 2 actions running
#     Compiling src/google/protobuf/message.cc [for host]; 2s local
# [146 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [146 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [147 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [147 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [147 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [148 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [148 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [149 / 188] 2 actions running
#     Compiling src/google/protobuf/extension_set_heavy.cc [for host]; 0s local
# [149 / 188] 2 actions running
#     Compiling src/google/protobuf/extension_set_heavy.cc [for host]; 0s local
# [149 / 188] 2 actions running
#     Compiling src/google/protobuf/extension_set_heavy.cc [for host]; 1s local
# [150 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [150 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [151 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/descriptor_database.cc [for host]; 0s local
# [151 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor_database.cc [for host]; 1s local
# [151 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor_database.cc [for host]; 2s local
# [151 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor_database.cc [for host]; 3s local
# [152 / 188] 2 actions running
#     Compiling src/google/protobuf/descriptor_database.cc [for host]; 3s local
# [153 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/compiler/importer.cc [for host]; 0s local
# [153 / 188] 2 actions running
#     Compiling src/google/protobuf/compiler/importer.cc [for host]; 0s local
# [153 / 188] 2 actions running
#     Compiling src/google/protobuf/compiler/importer.cc [for host]; 1s local
# [154 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [154 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [155 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [156 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [156 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [157 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [157 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [158 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [161 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/stubs/common.cc [for host]; 0s local
# [161 / 188] 2 actions running
#     Compiling src/google/protobuf/stubs/common.cc [for host]; 0s local
# [162 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/util/json_util.cc [for host]; 1s local
# [162 / 188] 2 actions running
#     Compiling src/google/protobuf/util/json_util.cc [for host]; 1s local
# [163 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/util/json_util.cc [for host]; 1s local
# [164 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/io/coded_stream.cc [for host]; 0s local
# [164 / 188] 2 actions running
#     Compiling src/google/protobuf/io/coded_stream.cc [for host]; 0s local
# [165 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/io/coded_stream.cc [for host]; 0s local
# [166 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [166 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [167 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [167 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [168 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [168 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [169 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [169 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [170 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [170 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 0s local
# [171 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [171 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [173 / 188] 2 actions, 0 running
#     [Scann] Compiling src/google/protobuf/map_field.cc [for host]
# [173 / 188] 2 actions running
#     Compiling src/google/protobuf/map_field.cc [for host]; 0s local
# [174 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/map_field.cc [for host]; 0s local
# [174 / 188] 2 actions running
#     Compiling src/google/protobuf/map_field.cc [for host]; 0s local
# [174 / 188] 2 actions running
#     Compiling src/google/protobuf/map_field.cc [for host]; 1s local
# [174 / 188] 2 actions running
#     Compiling src/google/protobuf/map_field.cc [for host]; 2s local
# [175 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/map_field.cc [for host]; 3s local
# [176 / 188] 2 actions, 1 running
#     Compiling src/google/protobuf/empty.pb.cc [for host]; 0s local
# [176 / 188] 2 actions running
#     Compiling src/google/protobuf/empty.pb.cc [for host]; 0s local
# [177 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [177 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [177 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [178 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 3s local
# [178 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 3s local
# [178 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 4s local
# [179 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 2s local
# [179 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [180 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [180 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [181 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 0s local
# [181 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 1s local
# [181 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [182 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protoc_lib; 1s local
# [182 / 188] 2 actions running
#     @com_google_protobuf//:protoc_lib; 2s local
# [183 / 188] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 0s local
# [183 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 0s local
# [183 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 2s local
# [183 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 3s local
# [183 / 188] 2 actions running
#     @com_google_protobuf//:protobuf; 4s local
# [184 / 201] 2 actions, 1 running
#     @com_google_protobuf//:protobuf; 4s local
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [203 / 211] 2 actions running
# [204 / 211] 2 actions, 1 running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [204 / 211] 2 actions running
# [205 / 211] 2 actions, 1 running
# [205 / 211] 2 actions running
# [205 / 211] 2 actions running
# [205 / 211] 2 actions running
# [205 / 211] 2 actions running
# [205 / 211] 2 actions running
# [205 / 211] 2 actions running
# [205 / 211] 2 actions running
# [205 / 211] 2 actions running
# [205 / 211] 2 actions running
# [205 / 211] 2 actions running
# [205 / 211] 2 actions running
# [206 / 211] 2 actions, 1 running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [206 / 211] 2 actions running
# [207 / 211] 2 actions, 1 running
# [207 / 211] 2 actions running
# [207 / 211] 2 actions running
# [207 / 211] 2 actions running
# [207 / 211] 2 actions running
# [207 / 211] 2 actions running
# [207 / 211] 2 actions running
# [207 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [208 / 211] 2 actions running
# [209 / 211] 2 actions running
# [209 / 211] 2 actions running
# [209 / 211] 2 actions running
# [209 / 211] 2 actions running
# [209 / 211] 2 actions running
# [209 / 211] 2 actions running
# [209 / 211] 2 actions running
# [209 / 211] 2 actions running
# [209 / 211] 2 actions running
# [210 / 211] 1 / 1 tests;  1 action; last test: .../layers:convolutional_test
# Target //keras/layers:convolutional_test up-to-date:
#   bazel-bin/keras/layers/convolutional_test
# INFO: Elapsed time: 335.844s, Critical Path: 47.44s
# INFO: 211 processes: 8 internal, 203 local.
# INFO: Build completed successfully, 211 total actions
# //keras/layers:convolutional_test                                        PASSED in 32.5s
#   Stats over 8 runs: max = 32.5s, min = 18.7s, avg = 22.9s, dev = 4.1s
#
# Executed 1 out of 1 test: 1 test passes.
# INFO: Build completed successfully, 211 total actions
